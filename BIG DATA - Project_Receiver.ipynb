# %% [markdown]
# # Revenue Fluctuation modelling

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *
import socket, time


lines = spark.readStream.format("socket")\
  .option("host", "localhost")\
  .option("port", 9975)\
  .load()

structuredStream = lines.select(\
  split(lines.value, ",")[0].cast('Timestamp').alias("Timestamp"),\
  split(lines.value, ",")[1].alias("vertical"),\
  split(lines.value, ",")[2].cast('Float').alias("revenue"),\
  split(lines.value, ",")[3].cast('Int').alias("impressions"))

# %% [markdown]
# ## 1. Define the window computation
#
# 4 days for overall computation period

# %%
# Generate window computation for 4 days

windowedStream = structuredStream.groupBy(window("Timestamp", "96 hours", "96 hours"))

# %% [markdown]
# ## 2. Aggregations
#
# Define aggregations for the window stream

# %%
agregationsStream = windowedStream.agg(avg("revenue").alias("revenue_average"), sum("revenue").alias("total_revenue"), count("Timestamp").alias("count"))

# %% [markdown]
# ## 3. Starting the stream

# %%
streamingETLQuery =\
agregationsStream \
  .writeStream \
  .format("memory") \
  .queryName("aggDF") \
  .outputMode("complete")\
  .start()

# %% [markdown]
# ## 4. Stopping the stream after 1 iteration to stop data from looping over (didn't work because the aggregation computation below has priority over the stop function)

# %%
#Defining the timeout
streamingETLQuery.awaitTermination(timeout = 210) 
streamingETLQuery.stop()

# %% [markdown]
# ## 5. Visualizing the stream contents to see if it makes sense
#
# Check if the stream works correctly and if the data is aggregated correctly

# %%
from pyspark.sql.functions import desc
#display(agregationsStream)
display(agregationsStream.sort(asc("window.start")))

# %% [markdown]
# ## 6. Computation and visualization of the resulting streaming dataframe

# %%
import math
import sys
from pyspark.sql.functions import asc
from pyspark.sql.window import Window
from pyspark.sql.functions import monotonically_increasing_id,row_number

df = spark.sql("select * from aggDF")
print("Running SQL....")

#Defining variables for iteration and the sliding window 
iter = 1
n = 1 
x = 4


prev_avg = 1.0
old_count = 0

while True:
  
  #
  if(df.count() != 0):
    while(old_count == df.count()):
      #
      continue
      
    # 
    old_count = df.count()
    
    print("*********************************************************************************************************")
    print("\nIteration no. "+ str(iter) + "\n")
    print("Sample data from streaming dataframe:\n")
    
    # set the time to be the end of the window and give an ID to each window
    df = df.withColumn("time", df.window.end)
    df = df.withColumn("row_idx",row_number().over(Window.orderBy(monotonically_increasing_id())))
       
    # Sort ascendingly in batches of 4
    df = df.sort(asc("time"))
    df.filter(df.row_idx.between(n,x)).show(truncate=False)

    print("Current number of windows processed in stream: "+ str(old_count) + "\n")

    #Aggregate the revenue  
    val = df.select('total_revenue').agg(sum('total_revenue')).collect()[0][0]

    #Calculate historical average
    counts = df.select('count').agg(sum('count')).collect()[0][0]
    if(counts != None and counts != 0):
      # update the historic average taking into account the new aggregated values
      historic_avg = val/counts

    #Use pretty printing
    for indent in range(iter - 1):
      sys.stdout.write("|****|")
    print ("|----|  Average price before current window: " + str(prev_avg))
    sys.stdout.flush()
    
    
    #Create a rule to iterate over 
    if iter == 1: 
        current_avg = df.select("revenue_average").take(1)[0][0]
    else: 
        current_avg = df.select("revenue_average").take(n)[n-1][0]
    
    #Use pretty printing
    for indent in range(iter - 1):
      sys.stdout.write("      ") 
    sys.stdout.write("|****| " + " Current window average price: " + str(current_avg))
    print

    #Calculate revenue 
    if((math.fabs(current_avg - prev_avg)/prev_avg) > 0.45 and iter > 1):
        print("\n\t!!! PRICE FLUCTUATION: price fluctuated by "+ str(float("{0:.2f}".format(math.fabs(current_avg - prev_avg)/prev_avg)) * 100) + " % !!!\n\n\n")
        
    #Add 4 to the variables for next batch    
    prev_avg = historic_avg
    n += 4
    x += 4
    iter += 1
# Out:
# Running SQL....
# *********************************************************************************************************
#
# Iteration no. 1
#
# Sample data from streaming dataframe:
#
# +------------------------------------------+------------------+------------------+-----+-------------------+-------+
# |window                                    |revenue_average   |total_revenue     |count|time               |row_idx|
# +------------------------------------------+------------------+------------------+-----+-------------------+-------+
# |{2022-09-01 00:00:00, 2022-09-05 00:00:00}|242.5999959309896 |727.7999877929688 |3    |2022-09-05 00:00:00|1      |
# |{2022-09-17 00:00:00, 2022-09-21 00:00:00}|284.8249969482422 |1139.2999877929688|4    |2022-09-21 00:00:00|2      |
# |{2022-09-29 00:00:00, 2022-10-03 00:00:00}|246.70000076293945|986.8000030517578 |4    |2022-10-03 00:00:00|4      |
# |{2022-10-15 00:00:00, 2022-10-19 00:00:00}|327.2249984741211 |1308.8999938964844|4    |2022-10-19 00:00:00|3      |
# +------------------------------------------+------------------+------------------+-----+-------------------+-------+
#
# Current number of windows processed in stream: 13
#
# |----|  Average price before current window: 1.0
# |****|  Current window average price: 242.5999959309896*********************************************************************************************************
#
# Iteration no. 2
#
# Sample data from streaming dataframe:
#
# +------------------------------------------+------------------+------------------+-----+-------------------+-------+
# |window                                    |revenue_average   |total_revenue     |count|time               |row_idx|
# +------------------------------------------+------------------+------------------+-----+-------------------+-------+
# |{2022-09-17 00:00:00, 2022-09-21 00:00:00}|284.8249969482422 |1139.2999877929688|4    |2022-09-21 00:00:00|5      |
# |{2022-09-21 00:00:00, 2022-09-25 00:00:00}|249.4000015258789 |997.6000061035156 |4    |2022-09-25 00:00:00|6      |
# |{2022-09-25 00:00:00, 2022-09-29 00:00:00}|283.1000061035156 |1132.4000244140625|4    |2022-09-29 00:00:00|7      |
# |{2022-09-29 00:00:00, 2022-10-03 00:00:00}|246.70000076293945|986.8000030517578 |4    |2022-10-03 00:00:00|8      |
# +------------------------------------------+------------------+------------------+-----+-------------------+-------+
#
# Current number of windows processed in stream: 18
#
# |****||----|  Average price before current window: 247.30000046552237
#       |****|  Current window average price: 284.8249969482422*********************************************************************************************************
#
# Iteration no. 3
#
# Sample data from streaming dataframe:
#
# +------------------------------------------+-----------------+------------------+-----+-------------------+-------+
# |window                                    |revenue_average  |total_revenue     |count|time               |row_idx|
# +------------------------------------------+-----------------+------------------+-----+-------------------+-------+
# |{2022-10-03 00:00:00, 2022-10-07 00:00:00}|287.3250045776367|1149.3000183105469|4    |2022-10-07 00:00:00|9      |
# |{2022-10-07 00:00:00, 2022-10-11 00:00:00}|327.5749969482422|1310.2999877929688|4    |2022-10-11 00:00:00|10     |
# |{2022-10-11 00:00:00, 2022-10-15 00:00:00}|302.0499954223633|1208.1999816894531|4    |2022-10-15 00:00:00|11     |
# |{2022-10-15 00:00:00, 2022-10-19 00:00:00}|327.2249984741211|1308.8999938964844|4    |2022-10-19 00:00:00|12     |
# +------------------------------------------+-----------------+------------------+-----+-------------------+-------+
#
# Current number of windows processed in stream: 22
#
# |****||****||----|  Average price before current window: 264.9223687021356
#             |****|  Current window average price: 287.3250045776367*********************************************************************************************************
#
# Iteration no. 4
#
# Sample data from streaming dataframe:
#
# +------------------------------------------+------------------+------------------+-----+-------------------+-------+
# |window                                    |revenue_average   |total_revenue     |count|time               |row_idx|
# +------------------------------------------+------------------+------------------+-----+-------------------+-------+
# |{2022-10-19 00:00:00, 2022-10-23 00:00:00}|318.8249969482422 |1275.2999877929688|4    |2022-10-23 00:00:00|13     |
# |{2022-10-23 00:00:00, 2022-10-27 00:00:00}|340.87500762939453|1363.5000305175781|4    |2022-10-27 00:00:00|14     |
# |{2022-10-27 00:00:00, 2022-10-31 00:00:00}|305.5249938964844 |1222.0999755859375|4    |2022-10-31 00:00:00|15     |
# |{2022-10-31 00:00:00, 2022-11-04 00:00:00}|329.5749969482422 |1318.2999877929688|4    |2022-11-04 00:00:00|16     |
# +------------------------------------------+------------------+------------------+-----+-------------------+-------+
#
# Current number of windows processed in stream: 24
#
# |****||****||****||----|  Average price before current window: 239.56666696199807
#                   |****|  Current window average price: 318.8249969482422*********************************************************************************************************
#
# Iteration no. 5
#
# Sample data from streaming dataframe:
#
# +------------------------------------------+------------------+------------------+-----+-------------------+-------+
# |window                                    |revenue_average   |total_revenue     |count|time               |row_idx|
# +------------------------------------------+------------------+------------------+-----+-------------------+-------+
# |{2022-11-04 00:00:00, 2022-11-08 00:00:00}|340.4250030517578 |1361.7000122070312|4    |2022-11-08 00:00:00|17     |
# |{2022-11-08 00:00:00, 2022-11-12 00:00:00}|201.3499984741211 |805.3999938964844 |4    |2022-11-12 00:00:00|18     |
# |{2022-11-12 00:00:00, 2022-11-16 00:00:00}|159.4000015258789 |637.6000061035156 |4    |2022-11-16 00:00:00|19     |
# |{2022-11-16 00:00:00, 2022-11-20 00:00:00}|120.94999885559082|483.7999954223633 |4    |2022-11-20 00:00:00|20     |
# +------------------------------------------+------------------+------------------+-----+-------------------+-------+
#
# Current number of windows processed in stream: 28
#
# |****||****||****||****||----|  Average price before current window: 216.48256893332945
#                         |****|  Current window average price: 340.4250030517578
# 	!!! PRICE FLUCTUATION: price fluctuated by 56.99999999999999 % !!!
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
